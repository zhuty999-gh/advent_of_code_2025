# %%
# %load_ext autoreload
# %autoreload 2
import solution, solution_p2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
inp_eg = solution.read_input("example.txt")

# %%
example_answer_part_1 = solution.count_splits(inp_eg)
print(f"Example Answer Part I: {example_answer_part_1}")
assert example_answer_part_1 == 21, f"Expected 21, but got {example_answer_part_1}"
# Out:
# Example Answer Part I: 21

# %%
inp = solution.read_input("input.txt")

# %%
part_1_ans = solution.count_splits(inp)
print(f"Part I Answer: {part_1_ans}")
# Out:
# Part I Answer: 1579

# %%
inp_eg = solution.read_input("example.txt")
example_answer_part_2 = solution_p2.path_finder(inp_eg)
print(f"Example Answer Part II: {example_answer_part_2}")
assert example_answer_part_2 == 40, f"Expected 40, but got {example_answer_part_1}"
# Out:
# processing needle=0, paths=1
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=1, paths=1
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=2, paths=2
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=3, paths=2
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=4, paths=4
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=5, paths=4
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=6, paths=8
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=7, paths=8
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=8, paths=13
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=9, paths=13
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=10, paths=20
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=11, paths=20
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=12, paths=26
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=13, paths=26
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=14, paths=40
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# Example Answer Part II: 40

# %%
inp = solution.read_input("input.txt")
answer_part_2 = solution_p2.path_finder(inp)
print(f"Answer Part II: {answer_part_2}")
# Out:
# processing needle=0, paths=1
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=1, paths=1
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=2, paths=2
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=3, paths=2
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=4, paths=4
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=5, paths=4
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=6, paths=8
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=7, paths=8
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=8, paths=13
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=9, paths=13
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=10, paths=23
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=11, paths=23
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=12, paths=39
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=13, paths=39
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=14, paths=62
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=15, paths=62
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=16, paths=90
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=17, paths=90
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=18, paths=123
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=19, paths=123
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=20, paths=158
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=21, paths=158
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=22, paths=254
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=23, paths=254
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=24, paths=461
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=25, paths=461
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=26, paths=817
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=27, paths=817
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=28, paths=1534
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=29, paths=1534
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=30, paths=2004
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=31, paths=2004
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=32, paths=2629
#   -> cord_tracer: 0.001s, merge: 0.000s, assign: 0.000s
# processing needle=33, paths=2629
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=34, paths=4073
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=35, paths=4073
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=36, paths=6299
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=37, paths=6299
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=38, paths=11346
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=39, paths=11346
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=40, paths=17466
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=41, paths=17466
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=42, paths=24796
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=43, paths=24796
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=44, paths=38307
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=45, paths=38307
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=46, paths=58997
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=47, paths=58997
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=48, paths=89127
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=49, paths=89127
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=50, paths=148135
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=51, paths=148135
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=52, paths=271749
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=53, paths=271749
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=54, paths=504577
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=55, paths=504577
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=56, paths=928798
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=57, paths=928798
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=58, paths=1775097
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=59, paths=1775097
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=60, paths=3049236
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=61, paths=3049236
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=62, paths=3699646
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=63, paths=3699646
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=64, paths=4892351
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=65, paths=4892351
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=66, paths=7634633
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=67, paths=7634633
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=68, paths=10211906
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=69, paths=10211906
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=70, paths=15404944
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=71, paths=15404944
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=72, paths=23623220
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=73, paths=23623220
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=74, paths=29352480
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=75, paths=29352480
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=76, paths=40247927
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=77, paths=40247927
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=78, paths=69500373
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=79, paths=69500373
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=80, paths=126926250
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=81, paths=126926250
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=82, paths=190612059
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=83, paths=190612059
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=84, paths=289240428
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=85, paths=289240428
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=86, paths=447025853
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=87, paths=447025853
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=88, paths=524313666
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=89, paths=524313666
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=90, paths=729397852
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=91, paths=729397852
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=92, paths=1034165209
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=93, paths=1034165209
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=94, paths=1331473557
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=95, paths=1331473557
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=96, paths=2019087257
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=97, paths=2019087257
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=98, paths=2759976472
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=99, paths=2759976472
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=100, paths=3915079707
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=101, paths=3915079707
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=102, paths=5949363184
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=103, paths=5949363184
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=104, paths=9380053260
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=105, paths=9380053260
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=106, paths=14829058110
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=107, paths=14829058110
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=108, paths=21465712368
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=109, paths=21465712368
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=110, paths=29586363102
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=111, paths=29586363102
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=112, paths=46717512116
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=113, paths=46717512116
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=114, paths=76837521102
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=115, paths=76837521102
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=116, paths=108333895763
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=117, paths=108333895763
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=118, paths=169586781213
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=119, paths=169586781213
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=120, paths=261608563229
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=121, paths=261608563229
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=122, paths=376081059134
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=123, paths=376081059134
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=124, paths=574869621766
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=125, paths=574869621766
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=126, paths=830367575481
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=127, paths=830367575481
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=128, paths=1269208799986
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=129, paths=1269208799986
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=130, paths=2042938497518
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=131, paths=2042938497518
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=132, paths=3158491543956
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=133, paths=3158491543956
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=134, paths=4610819190228
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=135, paths=4610819190228
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=136, paths=6113622067743
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=137, paths=6113622067743
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=138, paths=8631797723551
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=139, paths=8631797723551
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# processing needle=140, paths=13418215871354
#   -> cord_tracer: 0.000s, merge: 0.000s, assign: 0.000s
# Answer Part II: 13418215871354
