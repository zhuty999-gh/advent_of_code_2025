# %%
# %load_ext autoreload
# %autoreload 2
import main

# %%
egg = main.import_tiles("example.txt")
ans = main.find_largest_square_with_diagonals(egg)
print(f"part I example solution == {ans}")
# Out:
# part I example solution == 50

# %%
egg = main.import_tiles("input.txt")
ans = main.find_largest_square_with_diagonals(egg)
print(f"part I solution == {ans}")
# Out:
# part I solution == 4777409595

# %%
egg = main.import_tiles("example.txt")
green_tiles=main.find_green_tiles(egg)
main.visualize_tiles(egg, green_tiles)
ans = main.find_largest_square_with_diagonals_II(egg)
print(f"part II example solution == {ans}")
# Out:
# .............
# .......#XXX#.
# .......XXXXX.
# ..#XXXX#XXXX.
# ..XXXXXXXXXX.
# ..#XXXXXX#XX.
# .........XXX.
# .........#X#.
# .............
# part II example solution == 24

# %%
egg = main.import_tiles("input.txt")
ans = main.find_largest_square_with_diagonals_II(egg)
print(f"part II solution == {ans}")
# Out:
# part II solution == 1473551379
